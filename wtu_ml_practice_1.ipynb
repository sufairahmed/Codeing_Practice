# %% [markdown]
# <a href="https://colab.research.google.com/github/sufairahmed/ML_Practice/blob/master/wtu_ml_practice_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# ## Matplotlib Scatter Function use

# %%
#scatter
n = 1024
X = np.random.normal(0, 1, n)
Y = np.random.normal(0, 1, n)
T = np.arctan2(Y, X)

plt.figure()
plt.scatter(X, Y, s = 75, c = T, alpha = 0.5)
# plt.scatter(np.arange(10), np.arange(10))

# %% [markdown]
# ## Matplotlib Plot Function use

# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.arange(0, 10, 0.1)
y1 = 0.05 * x**2
y2 = -1 * y1

fig, ax1 = plt.subplots()
# fig, ax2 = plt.subplots()

ax2 = ax1.twinx() # mirror the ax1
ax1.plot(x,y1, 'g-')
ax2.plot(x,y2, 'b-')

ax1.set_xlabel('X data')
ax1.set_ylabel('Y1 data', color = 'w')
ax2.set_ylabel('Y2 data', color = 'r')

plt.show()

# %% [markdown]
# ## Numpy Linalg Norm

# %%
# import numpy as np
# x = np.array([
#             [0, 3, 4],
#             [1, 6, 4]])

# print("Two dimensional array: ", np.linalg.norm(x))
# print('Two square sum root number: ', np.linalg.norm(x, keepdims=True))

# print("some thing will be here: ", np.linalg.norm(x, axis = 1, keepdims=True))
# print("some thing will be here: ", np.linalg.norm(x, axis = 0, keepdims=True))

# print("some thing : ", np.linalg.norm(x, ord= 1, keepdims=True))

# %% [markdown]
# ## Pandas train_test_split

# %%
import pandas as pd
from sklearn.model_selection import train_test_split

namelist = pd.DataFrame({
    "name" : ['Suzuki', 'Tanaka', 'Yamada', 'Watanabe', 'Yamamoto', 'Okada',
              'Ueda', 'Inoue', 'Hayashi', 'Sato', 'Hirayama', 'Shimada'],
    "age" :[30, 40, 55, 29, 41, 28, 42, 24, 33, 39, 49, 53],
    "department" : ['HR', 'Legal', 'IT', 'HR', 'HR', 'IT', 'Legal','Legal', 'IT',
                    'HR','LEGAL','lEGAL'],
    "attendance": [1, 1, 1, 0, 1, 1, 1, 0, 0, 1, 1, 1]
})

print(namelist)
namelist_train, namelist_test = train_test_split(namelist, test_size= 0.3)
print ("-------------- Train dataset -------\n", namelist_train)
print ("-------------- Test dataset ---------\n", namelist_test)
# Out:
#         name  age department  attendance
# 0     Suzuki   30         HR           1
# 1     Tanaka   40      Legal           1
# 2     Yamada   55         IT           1
# 3   Watanabe   29         HR           0
# 4   Yamamoto   41         HR           1
# 5      Okada   28         IT           1
# 6       Ueda   42      Legal           1
# 7      Inoue   24      Legal           0
# 8    Hayashi   33         IT           0
# 9       Sato   39         HR           1
# 10  Hirayama   49      LEGAL           1
# 11   Shimada   53      lEGAL           1
# -------------- Train dataset -------
#          name  age department  attendance
# 10  Hirayama   49      LEGAL           1
# 4   Yamamoto   41         HR           1
# 6       Ueda   42      Legal           1
# 2     Yamada   55         IT           1
# 11   Shimada   53      lEGAL           1
# 1     Tanaka   40      Legal           1
# 0     Suzuki   30         HR           1
# 3   Watanabe   29         HR           0
# ...

# %% [markdown]
# ###Pandas iloc function

# %%
import numpy as np
import pandas as pd

df = pd.DataFrame(np.arange(16).reshape((4,4)), index=list(range(4)), columns=['a','b','c','d'] )

print(df)
print(df.iloc[:3, [0, 1, -1]])
# Out:
#     a   b   c   d
# 0   0   1   2   3
# 1   4   5   6   7
# 2   8   9  10  11
# 3  12  13  14  15
#    a  b   d
# 0  0  1   3
# 1  4  5   7
# 2  8  9  11

# %% [markdown]
# ## Collection Counter

# %%
from collections import Counter
c = Counter()
for ch in 'porgramming':
    c[ch] = c[ch]+ 1

print(c)
# Out:
# Counter({'r': 2, 'g': 2, 'm': 2, 'p': 1, 'o': 1, 'a': 1, 'i': 1, 'n': 1})

# %% [markdown]
# ## Sklearn iris

# %%
import matplotlib.pyplot as plt

from sklearn.datasets import load_iris

iris = load_iris()
df = pd.DataFrame (iris.data, columns=iris.feature_names)
df['label'] = iris.target
df.columns = ['sepal length', 'sepal width', 'petal length', 'petal width','label']

plt.scatter(df[:50]['sepal length'], df[:50]['sepal width'], label = '0')
plt.scatter(df[50:100]['sepal length'], df[50:100]['sepal width'], label = '1')

plt.xlabel('sepal length')
plt.ylabel('sepal width')
plt.legend()
